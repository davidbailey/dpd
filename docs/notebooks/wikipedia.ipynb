# %% [markdown]
# # Wikipedia

# %%
from dpd.wikipedia import get_wikipedia_table

# %%
get_wikipedia_table(
    "https://en.wikipedia.org/wiki/List_of_10-meter_diving_platforms_in_the_United_States",
    1,
)
# Out:
#    Image                                           Facility            City  \
# 0             Alabama Aquatic Center, University of Alabama      Tuscaloosa
# 1         James E. Martin Aquatics Center, Auburn Univer...          Auburn
# 2         NAU Aquatic and Tennis Complex, Northern Arizo...       Flagstaff
# 3         Mona Plummer Aquatic Center, Arizona State Uni...           Tempe
# 4         Hillenbrand Aquatic Center, University of Arizona          Tucson
# ..   ...                                                ...             ...
# 68                       Kearns Oquirrh Park Fitness Center  Salt Lake City
# 69              Christiansburg Aquatic Center Virginia Tech      Blacksburg
# 70                   Liberty Natatorium, Liberty University       Lynchburg
# 71                              Weyerhaeuser Aquatic Center     Federal Way
# 72                          Walter Schroeder Aquatic Center      Brown Deer
#
#          State                                 Note
# ...
