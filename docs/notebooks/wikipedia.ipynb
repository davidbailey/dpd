# %% [markdown]
# # Wikipedia

# %%
from dpd.wikipedia import get_wikipedia_table

# %%
get_wikipedia_table("https://en.wikipedia.org/wiki/List_of_10-meter_diving_platforms_in_the_United_States")
# Out:
#                                              Platform Image  \
# 0                                   10 meter platform
# 1                                   10 meter platform
# 2                                   10 meter platform
# 3                                   10 meter platform
# 4                                   10 meter platform
# 5                                   10 meter platform
# 6                                   10 meter platform
# 7                                   10 meter platform
# 8                                   10 meter platform
# 9                                   10 meter platform
# 10                                  10 meter platform
# 11                                  10 meter platform
# 12                                  10 meter platform
# 13              10 meter platform, Maas Diving Center
# 14                                  10 meter platform
# 15                                  10 meter platform
# ...
